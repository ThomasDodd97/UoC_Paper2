# %%
# This code is for an FTIR comparison between the DMI-rich product generated
# after rotary evaporation and the pure itaconic acid reagent used
# during reflux.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as image
from matplotlib.offsetbox import (OffsetImage, AnnotationBbox)

# %%
IA_df = pd.read_csv("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper2/Sandbox/FTIR/PureReagent_IA.csv")
DMI_df = pd.read_csv("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper2/Sandbox/FTIR/RotaryEvaporatorProduct_DMI.csv")
CDMI_df = pd.read_csv("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper2/Sandbox/FTIR/CrystallineDMI.csv")

# %%
IA_x = np.array(IA_df["3.996813e+02"])
IA_y = np.array(IA_df["0.000000e+00"])

DMI_x = np.array(DMI_df["3.996813e+02"])
DMI_y = np.array(DMI_df["0.000000e+00"])

CDMI_x = np.array(CDMI_df["3.996813e+02"])
CDMI_y = np.array(CDMI_df["0.000000e+00"])

# %%
# fig, ax1 = plt.subplots(figsize=(8, 4),dpi=80)
fig, ax1 = plt.subplots(figsize=(4, 4),dpi=160)
ax1.plot(IA_x,IA_y,color="blue",label="Itaconic Acid")
# ax1.set_xlim(500,4000)
ax1.set_ylabel("Transmittance (%)")
ax1.set_xlabel(r"Wavenumber (cm$^{-1}$)")
ax1.invert_xaxis()
# ax1.set_ylim(40,100)
ax1.set_yticks([])
# Out:
# []

# %%
# fig, ax1 = plt.subplots(figsize=(8, 4),dpi=80)
fig, ax1 = plt.subplots(figsize=(4, 4),dpi=160)
ax1.plot(IA_x,IA_y,color="blue",label="Itaconic Acid")
ax1.set_xlim(500,4000)
ax1.set_ylabel("Transmittance (%)")
ax1.set_xlabel(r"Wavenumber (cm$^{-1}$)")
ax1.invert_xaxis()
ax1.set_ylim(40,100)
ax1.set_yticks([])

ax2 = ax1.twinx()
ax2.plot(DMI_x,DMI_y,color="red",label="Dimethyl Itaconate")
ax2.set_ylim(10,200)
ax2.set_yticks([])

ax1.axhline(y=70,xmin=0,xmax=1,color="black",linewidth=1)
ax1.text(x=400,y=79,s="Itaconic Acid",rotation="vertical")
ax1.text(x=400,y=52,s="Product",rotation="vertical")

ax1.text(x=2900,y=97,s="A")
ax1.arrow(x=2945,y=98,dx=180,dy=0,width=0.1,head_length=50,head_width=1,color="black",alpha=0.6)
ax1.arrow(x=2770,y=98,dx=-190,dy=0,width=0.1,head_length=50,head_width=1,color="black",alpha=0.6)

ax1.axvline(x=2500,ymin=0,ymax=1,linestyle="dashed",color="black",alpha=0.5)
ax1.axvline(x=3200,ymin=0.7,ymax=1,linestyle="dashed",color="black",alpha=0.5)
ax1.axvline(x=3200,ymin=0.25,ymax=0.52,linestyle="dashed",color="black",alpha=0.5)
ax1.axvline(x=3200,ymin=0,ymax=0.06,linestyle="dashed",color="black",alpha=0.5)

ax1.text(x=1735,y=71,s="B")
ax1.text(x=1730,y=74,s=u"\u25B2",fontsize=7)

ax1.text(x=1655,y=81.7,s="C")
ax1.text(x=1650,y=84.7,s=u"\u25B2",fontsize=7)

ax1.text(x=1755,y=42.2,s="D")
ax1.text(x=1750,y=45.2,s=u"\u25B2",fontsize=7)

ax1.text(x=1668,y=57,s="E")
ax1.text(x=1664,y=60,s=u"\u25B2",fontsize=7)

ax1.text(x=3020,y=89,s="F")
ax1.text(x=3050,y=92.2,s=u"\u25B2",fontsize=5)
ax1.text(x=2950,y=91.7,s=u"\u25B2",fontsize=5)

ax1.text(x=3000,y=59,s="G")
ax1.text(x=3035,y=64.2,s=u"\u25B2",fontsize=5)
ax1.text(x=3000,y=63,s=u"\u25B2",fontsize=5)
ax1.text(x=2980,y=62,s=u"\u25B2",fontsize=5)
ax1.text(x=2930,y=65,s=u"\u25B2",fontsize=5)
ax1.text(x=2875,y=64.9,s=u"\u25B2",fontsize=5)

file = "/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper2/Sandbox/rdkit/DMI.png"
logo = image.imread(file)
imagebox = OffsetImage(logo, zoom = 0.23)
ab = AnnotationBbox(imagebox, (3250, 50), frameon = False)
ax1.add_artist(ab)

file = "/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper2/Sandbox/rdkit/IA.png"
logo = image.imread(file)
imagebox = OffsetImage(logo, zoom = 0.23)
ab = AnnotationBbox(imagebox, (3300, 78), frameon = False)
ax1.add_artist(ab)

fig.tight_layout()
plt.show()

# %% [markdown]
# # Redrawing With Crystalline DMI

# %%
# fig, ax1 = plt.subplots(figsize=(8, 4),dpi=80)
fig, ax1 = plt.subplots(figsize=(4, 4),dpi=160)
ax1.plot(IA_x,IA_y,color="blue",label="Itaconic Acid")
ax1.set_xlim(500,4000)
ax1.set_ylabel("Transmittance (%)")
ax1.set_xlabel(r"Wavenumber (cm$^{-1}$)")
ax1.invert_xaxis()
ax1.set_ylim(40,100)
ax1.set_yticks([])

ax2 = ax1.twinx()
ax2.plot(CDMI_x,CDMI_y,color="red",label="Dimethyl Itaconate")
ax2.set_ylim(15,210)
ax2.set_yticks([])

ax1.axhline(y=70,xmin=0,xmax=1,color="black",linewidth=1)
ax1.text(x=400,y=79,s="Itaconic Acid",rotation="vertical")
ax1.text(x=400,y=52,s="Product",rotation="vertical")

ax1.text(x=2900,y=97,s="A")
ax1.arrow(x=2945,y=98,dx=180,dy=0,width=0.1,head_length=50,head_width=1,color="black",alpha=0.6)
ax1.arrow(x=2770,y=98,dx=-190,dy=0,width=0.1,head_length=50,head_width=1,color="black",alpha=0.6)

ax1.axvline(x=2500,ymin=0,ymax=1,linestyle="dashed",color="black",alpha=0.5)
ax1.axvline(x=3200,ymin=0.7,ymax=1,linestyle="dashed",color="black",alpha=0.5)
ax1.axvline(x=3200,ymin=0.25,ymax=0.52,linestyle="dashed",color="black",alpha=0.5)
ax1.axvline(x=3200,ymin=0,ymax=0.06,linestyle="dashed",color="black",alpha=0.5)

ax1.text(x=1735,y=71,s="B")
ax1.text(x=1730,y=74,s=u"\u25B2",fontsize=7)

ax1.text(x=1655,y=81.7,s="C")
ax1.text(x=1650,y=84.7,s=u"\u25B2",fontsize=7)

ax1.text(x=1755,y=41.5,s="D")
ax1.text(x=1750,y=44.5,s=u"\u25B2",fontsize=7)

ax1.text(x=1668,y=49.8,s="E")
ax1.text(x=1664,y=52.8,s=u"\u25B2",fontsize=7)

ax1.text(x=3020,y=89,s="F")
ax1.text(x=3050,y=92.2,s=u"\u25B2",fontsize=5)
ax1.text(x=2950,y=91.7,s=u"\u25B2",fontsize=5)

ax1.text(x=3000,y=58,s="G")
ax1.text(x=3035,y=62.7,s=u"\u25B2",fontsize=5)
ax1.text(x=2980,y=60.7,s=u"\u25B2",fontsize=5)
ax1.text(x=2875,y=64.9,s=u"\u25B2",fontsize=5)

file = "/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper2/Sandbox/rdkit/DMI.png"
logo = image.imread(file)
imagebox = OffsetImage(logo, zoom = 0.23)
ab = AnnotationBbox(imagebox, (3250, 50), frameon = False)
ax1.add_artist(ab)

file = "/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/writing/papers/UoC_Paper2/Sandbox/rdkit/IA.png"
logo = image.imread(file)
imagebox = OffsetImage(logo, zoom = 0.23)
ab = AnnotationBbox(imagebox, (3300, 78), frameon = False)
ax1.add_artist(ab)

fig.tight_layout()
plt.show()

# %% [markdown]
# # Looking at C-H

# %%
# fig, ax1 = plt.subplots(figsize=(8, 4),dpi=80)
fig, ax1 = plt.subplots(figsize=(4, 4),dpi=160)
ax1.plot(IA_x,IA_y,color="blue",label="Itaconic Acid")
ax1.set_xlim(2000,3500)
ax1.set_ylabel("Transmittance (%)")
ax1.set_xlabel(r"Wavenumber (cm$^{-1}$)")
ax1.invert_xaxis()
ax1.set_ylim(92,100)

ax1.axvline(x=2800,ymin=0,ymax=1,color="green")
ax1.axvline(x=3000,ymin=0,ymax=1,color="green")

ax1.axvline(x=2980,ymin=0,ymax=1,color="red")
ax1.axvline(x=3170,ymin=0,ymax=1,color="red")

# %%
# fig, ax1 = plt.subplots(figsize=(8, 4),dpi=80)
fig, ax1 = plt.subplots(figsize=(4, 4),dpi=160)
ax1.plot(DMI_x,DMI_y,color="blue",label="Itaconic Acid")
ax1.set_xlim(2500,3400)
ax1.set_ylabel("Transmittance (%)")
ax1.set_xlabel(r"Wavenumber (cm$^{-1}$)")
ax1.invert_xaxis()
ax1.set_ylim(85,100)

ax1.axvline(x=2800,ymin=0,ymax=1,color="green")
ax1.axvline(x=3000,ymin=0,ymax=1,color="green")

ax1.axvline(x=2980,ymin=0,ymax=1,color="red")
ax1.axvline(x=3170,ymin=0,ymax=1,color="red")

# %%
# fig, ax1 = plt.subplots(figsize=(8, 4),dpi=80)
fig, ax1 = plt.subplots(figsize=(4, 4),dpi=160)
ax1.plot(CDMI_x,CDMI_y,color="blue",label="Itaconic Acid")
ax1.set_xlim(2700,3200)
ax1.set_ylabel("Transmittance (%)")
ax1.set_xlabel(r"Wavenumber (cm$^{-1}$)")
ax1.invert_xaxis()
ax1.set_ylim(84,105)

ax1.axvline(x=2800,ymin=0,ymax=1,color="green")
ax1.axvline(x=3000,ymin=0,ymax=1,color="green")

ax1.axvline(x=2980,ymin=0,ymax=1,color="red")
ax1.axvline(x=3170,ymin=0,ymax=1,color="red")
