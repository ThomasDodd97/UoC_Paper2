# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from ax import Client
import matplotlib as mpl

# %%
df = pd.read_csv("/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/Project-2_BO4ACST/ExperimentalSeries-2_TOoUPRCS/Method20250625Dim3_CurSys_qLNEI_UCSvYM/Backup.csv")
x_mat = np.array([np.array(df["x1"]),np.array(df["x2"]),np.array(df["x3"])])

# %%
AxClient_obj = Client.load_from_json_file('/Users/thomasdodd/Library/CloudStorage/OneDrive-MillfieldEnterprisesLimited/Cambridge/PhD/Project-2_BO4ACST/ExperimentalSeries-2_TOoUPRCS/Method20250625Dim3_CurSys_qLNEI_UCSvYM/AxExperiment.json')
UcsYm_mat = np.array([np.array(AxClient_obj.summarize()["ucs"]),np.array(AxClient_obj.summarize()["ym"])])

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.scatter(x_mat[0][0:8],x_mat[1][0:8],x_mat[2][0:8])
ax.view_init(elev=30, azim=45, roll=0)
ax.set_xlabel(r'$x_{1}$')
ax.set_ylabel(r'$x_{2}$')
ax.set_zlabel(r'$x_{3}$')
ax.set_xlim(0.45,1)
ax.set_ylim(0.4,1)
ax.set_zlim(0.5,0.95)
# Out:
# (0.5, 0.95)

# %%
# %matplotlib widget
ax = plt.figure().add_subplot(projection='3d')
ax.scatter(x_mat[0],x_mat[1],x_mat[2],c=UcsYm_mat[0])
ax.view_init(elev=30, azim=45, roll=0)
ax.set_xlabel(r'$x_{1}$')
ax.set_ylabel(r'$x_{2}$')
ax.set_zlabel(r'$x_{3}$')
ax.set_xlim(0.45,1)
ax.set_ylim(0.4,1)
ax.set_zlim(0.5,0.95)
# Out:
# (0.5, 0.95)
