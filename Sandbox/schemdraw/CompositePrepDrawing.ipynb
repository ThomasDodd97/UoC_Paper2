# %%
import schemdraw
from schemdraw import flow
from schemdraw.elements import Gap
from schemdraw.segments import Segment
from schemdraw.elements import Line

# %% [markdown]
# # Attempt 1

# %%
with schemdraw.Drawing() as d:
    d.config(fontsize=11,unit=1)
    CUPR = flow.Start(w=4,h=0.8).label('Cured Unsaturated\nPolyester Resin').linestyle(":")
    flow.Arrow().down(d.unit).reverse().label(r"3 hr @ 80 $^{\circ}$C" "\n" r"1 hr @ 120 $^{\circ}$C",loc="bottom").label("Heating",loc="top")
    
    IUPR = flow.Start(w=4,h=0.8).label('Initiated Unsaturated\nPolyester Resin').linestyle(":")

    flow.Arrow(arrowwidth=0.01).left(d.unit/2).at(IUPR.W).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit).linewidth(0.01).color('white') # hacky gap
    I2 = flow.Start(w=2,h=0.8).label('Initiating\nAgent 2').linestyle(":")
    flow.Wire('|-', arrow='->').at(I2.N).to(IUPR.W).label(r"$1-x_3$",ofst=[-0.8,-0.5]).linestyle(":")

    flow.Arrow(arrowwidth=0.01).right(d.unit/2).at(IUPR.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit).linewidth(0.01).color('white') # hacky gap
    UPR2 = flow.Start(w=3,h=0.8).label('Unsaturated\nPolyester Resin 2').linestyle(":")
    flow.Wire('|-', arrow='->').at(UPR2.N).to(IUPR.E).label(r"$x_3$",ofst=[0.6,-0.5]).linestyle(":")

    flow.Arrow().down(d.unit*2).at(I2.S).reverse().label(r"$x_2$",ofst=[0,0]).linestyle(":")
    I1 = flow.Start(w=2,h=0.8).label('Initiating\nAgent 1')
    flow.Arrow(arrowwidth=0.01).right(d.unit).at(I1.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    CS2 = flow.Start(w=2.3,h=0.8).anchor('S').label('Calcium\nSulphate 2')
    flow.Wire('|-', arrow='->').at(CS2.N).to(I2.E).label(r"$1-x_2$",ofst=[1.1,-0.6]).linestyle(":")

    flow.Arrow().down(d.unit*2).at(UPR2.S).reverse().label(r"$x_1$",ofst=[0,0]).linestyle(":")
    UPR1 = flow.Start(w=3,h=0.8).label('Unsaturated\nPolyester Resin 1')
    flow.Arrow(arrowwidth=0.01).right(d.unit/2).at(UPR1.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    DMI2 = flow.Start(w=2.3,h=0.8).anchor('S').label('Dimethyl\nItaconate 2')
    flow.Wire('|-', arrow='->').at(DMI2.N).to(UPR2.E).label(r"$1-x_1$",ofst=[0.8,-0.6]).linestyle(":")

    flow.Arrow().down(d.unit*2).at(I1.S).reverse().label(r"$1-c_2$",ofst=[0,0])
    DBP = flow.Start(w=2.3,h=0.8).label('Dibenzoyl\nPeroxide')
    flow.Arrow(arrowwidth=0.01).right(d.unit*0.85).at(DBP.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    CS2 = flow.Start(w=2.3,h=0.8).anchor('S').label('Calcium\nSulphate 1')
    flow.Wire('|-', arrow='->').at(CS2.N).to(I1.E).label(r"$c_2$",ofst=[0.8,-0.6])

    flow.Arrow().down(d.unit*2).at(UPR1.S).reverse().label(r"$c_1$",ofst=[0,0])
    UP = flow.Start(w=2.3,h=0.8).label('Unsaturated\nPolyester')
    flow.Arrow(arrowwidth=0.01).right(d.unit*0.85).at(UP.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    DMI1 = flow.Start(w=2.3,h=0.8).anchor('S').label('Dimethyl\nItaconate 1')
    flow.Wire('|-', arrow='->').at(DMI1.N).to(UPR1.E).label(r"$1-c_1$",ofst=[0.8,-0.6])

    # Legend Item 1 (variable elements)
    flow.Arrow(arrowwidth=0.01).at(DBP.W).down(d.unit*1.2).linewidth(0.01).color('white') # hacky gap
    VarComp = flow.Start(w=5.2,h=0.5).anchor("W").label('Variable Composition Element').linestyle(":")
    flow.Arrow().at(VarComp.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*3.5).label("Variable Mass Ratio",ofst=[0,-0.1]).linestyle(":")

    # Legend Item 2 (invariable elements)
    flow.Arrow(arrowwidth=0.01).at(VarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    InVarComp = flow.Start(w=5.2,h=0.5).anchor("W").label('Invariable Composition Element').linestyle("-")
    flow.Arrow(arrowwidth=0.01).at(InVarComp.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*3.5).label("Invariable Mass Ratio",ofst=[0,-0.1])

    # Legend Item 3 (Manufacturing Notes)
    flow.Arrow(arrowwidth=0.01).at(InVarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    SubProcess = flow.Box(w=9.2,h=0.5).anchor("W").label('Sub-Process').linestyle("-.")

    # Manufacturer Box
    flow.Arrow(arrowwidth=0.01).at(I1.W).down(d.unit*1.35).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.3).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.55,h=4.2).anchor("W").color("red").linestyle("-.").label("A",ofst=[2,1.7])

    # UPR Synthesis Box
    flow.Arrow(arrowwidth=0.01).at(UPR1.W).down(d.unit*1.35).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.1).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.85,h=4.2).anchor("W").color("blue").linestyle("-.").label("B",ofst=[2.2,1.7])

    # I2 Mixing Box
    seg = Segment(path=[(0, 0), (1, 0), (1, 1), (0, 1)])
    seg.draw()

    # UPR2 Mixing Box

    # IUPR Mixing Box

    # Curing Box

    d.save('CompositePreparation.png',transparent=False,dpi=1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 74
#      72 # I2 Mixing Box
#      73 seg = Segment(path=[(0, 0), (1, 0), (1, 1), (0, 1)])
# ---> 74 seg.draw()
#      76 # UPR2 Mixing Box
#      77
#      78 # IUPR Mixing Box
#      79
#      80 # Curing Box
#      82 d.save('CompositePreparation.png',transparent=False,dpi=1000)
#
# TypeError: Segment.draw() missing 2 required positional arguments: 'fig' and 'transform'

# %% [markdown]
# # Attempt 2

# %%
with schemdraw.Drawing() as d:
    d.config(fontsize=11,unit=1)
    CUPR = flow.Start(w=4,h=0.8).label('Cured Unsaturated\nPolyester Resin').linestyle("--")
    flow.Arrow().down(d.unit*1.2).reverse().label(r"3 hr @ 80 $^{\circ}$C" "\n" r"1 hr @ 120 $^{\circ}$C",loc="bottom").label("Heating",loc="top")
    
    IUPR = flow.Start(w=4,h=0.8).label('Initiated Unsaturated\nPolyester Resin').linestyle("--")

    flow.Arrow(arrowwidth=0.01).left(d.unit/1.5).at(IUPR.W).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*1.5).linewidth(0.01).color('white') # hacky gap
    I2 = flow.Start(w=2,h=0.8).label('Initiating\nAgent 2').linestyle("--")
    flow.Wire('|-', arrow='->').at(I2.N).to(IUPR.W).label(r"$1-x_3$",ofst=[-0.9,-0.5]).linestyle("--")

    flow.Arrow(arrowwidth=0.01).right(d.unit/1.2).at(IUPR.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*1.5).linewidth(0.01).color('white') # hacky gap
    UPR2 = flow.Start(w=3,h=0.8).label('Unsaturated\nPolyester Resin 2').linestyle("--")
    flow.Wire('|-', arrow='->').at(UPR2.N).to(IUPR.E).label(r"$x_3$",ofst=[0.7,-0.5]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(I2.S).reverse().label(r"$x_2$",ofst=[0,0]).linestyle("--")
    I1 = flow.Start(w=2,h=0.8).label('Initiating\nAgent 1')
    flow.Arrow(arrowwidth=0.01).right(d.unit).at(I1.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    CS2 = flow.Start(w=2.3,h=0.8).anchor('S').label('Calcium\nSulphate 2')
    flow.Wire('|-', arrow='->').at(CS2.N).to(I2.E).label(r"$1-x_2$",ofst=[1.1,-0.6]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(UPR2.S).reverse().label(r"$x_1$",ofst=[0,0]).linestyle("--")
    UPR1 = flow.Start(w=3,h=0.8).label('Unsaturated\nPolyester Resin 1')
    flow.Arrow(arrowwidth=0.01).right(d.unit/2).at(UPR1.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    DMI2 = flow.Start(w=2.3,h=0.8).anchor('S').label('Dimethyl\nItaconate 2')
    flow.Wire('|-', arrow='->').at(DMI2.N).to(UPR2.E).label(r"$1-x_1$",ofst=[0.8,-0.6]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(I1.S).reverse().label(r"$1-c_2$",ofst=[0,0])
    DBP = flow.Start(w=2.3,h=0.8).label('Dibenzoyl\nPeroxide')
    flow.Arrow(arrowwidth=0.01).right(d.unit*0.85).at(DBP.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    CS2 = flow.Start(w=2.3,h=0.8).anchor('S').label('Calcium\nSulphate 1')
    flow.Wire('|-', arrow='->').at(CS2.N).to(I1.E).label(r"$c_2$",ofst=[0.8,-0.6])

    flow.Arrow().down(d.unit*2.5).at(UPR1.S).reverse().label(r"$c_1$",ofst=[0,0])
    UP = flow.Start(w=2.3,h=0.8).label('Unsaturated\nPolyester')
    flow.Arrow(arrowwidth=0.01).right(d.unit*0.85).at(UP.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    DMI1 = flow.Start(w=2.3,h=0.8).anchor('S').label('Dimethyl\nItaconate 1')
    flow.Wire('|-', arrow='->').at(DMI1.N).to(UPR1.E).label(r"$1-c_1$",ofst=[0.8,-0.6])

    # Legend Item 1 (variable elements)
    flow.Arrow(arrowwidth=0.01).at(DBP.W).down(d.unit*1.2).linewidth(0.01).color('white') # hacky gap
    VarComp = flow.Start(w=5.2,h=0.5).anchor("W").label('Variable Composition Element').linestyle("--")
    flow.Arrow().at(VarComp.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*3.5).label("Variable Mass Ratio",ofst=[0,-0.1]).linestyle("--")

    # Legend Item 2 (invariable elements)
    flow.Arrow(arrowwidth=0.01).at(VarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    InVarComp = flow.Start(w=5.2,h=0.5).anchor("W").label('Invariable Composition Element').linestyle("-")
    flow.Arrow(arrowwidth=0.01).at(InVarComp.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*3.5).label("Invariable Mass Ratio",ofst=[0,-0.1])

    # Legend Item 3 (Manufacturing Notes)
    flow.Arrow(arrowwidth=0.01).at(InVarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    SubProcess = flow.Box(w=9.2,h=0.5).anchor("W").label('Sub-Process').linestyle(":")

    # Manufacturer Box
    flow.Arrow(arrowwidth=0.01).at(I1.W).down(d.unit*1.65).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.3).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.55,h=4.6).anchor("W").color("#43aa8b").linestyle(":").label("E",ofst=[2,2])

    # UPR Synthesis Box
    flow.Arrow(arrowwidth=0.01).at(UPR1.W).down(d.unit*1.65).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.1).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.85,h=4.6).anchor("W").color("#90be6d").linestyle(":").label("F",ofst=[2.15,2])

    # I2 Mixing Box
    flow.Arrow(arrowwidth=0.01).at(I2.W).down(d.unit*1.8).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.15).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.55,h=4.8).anchor("W").color("#f3722c").linestyle(":").label("C",ofst=[2,2.1])

    # UPR2 Mixing Box
    flow.Arrow(arrowwidth=0.01).at(UPR2.W).down(d.unit*1.8).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.25).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=5.2,h=4.8).anchor("W").color("#f9c74f").linestyle(":").label("D",ofst=[2.32,2.1])

    # IUPR Mixing Box
    flow.Arrow(arrowwidth=0.01).at(IUPR.W).down(d.unit*1.1).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*2).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=10.4,h=3.3).anchor("W").color("#577590").linestyle(":").label("B",ofst=[4.9,1.3])

    # IUPR Curing
    flow.Arrow(arrowwidth=0.01).at(CUPR.W).down(d.unit*1).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.4).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.9,h=3.2).anchor("W").color("#f94144").linestyle(":").label("A",ofst=[2.2,1.3])

    d.save('CompositePreparation.png',transparent=False,dpi=1000)

# %% [markdown]
# # Attempt 3

# %%
with schemdraw.Drawing() as d:
    d.config(fontsize=11,unit=1)
    CUPR = flow.Start(w=4,h=0.8).label('Cured Unsaturated\nPolyester Resin').linestyle("--")
    flow.Arrow().down(d.unit*1.2).reverse().label(r"3 hr @ 80 $^{\circ}$C" "\n" r"1 hr @ 120 $^{\circ}$C",loc="bottom").label("Heating",loc="top")
    
    IUPR = flow.Start(w=4,h=0.8).label('Initiated Unsaturated\nPolyester Resin').linestyle("--")

    flow.Arrow(arrowwidth=0.01).left(d.unit/1.5).at(IUPR.W).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*1.5).linewidth(0.01).color('white') # hacky gap
    I2 = flow.Start(w=2,h=0.8).label('Initiating\nAgent 2').linestyle("--")
    flow.Wire('|-', arrow='->').at(I2.N).to(IUPR.W).label(r"$1-x_3$",ofst=[-0.9,-0.5]).linestyle("--")

    flow.Arrow(arrowwidth=0.01).right(d.unit/1.2).at(IUPR.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*1.5).linewidth(0.01).color('white') # hacky gap
    UPR2 = flow.Start(w=3,h=0.8).label('Unsaturated\nPolyester Resin 2').linestyle("--")
    flow.Wire('|-', arrow='->').at(UPR2.N).to(IUPR.E).label(r"$x_3$",ofst=[0.7,-0.5]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(I2.S).reverse().label(r"$x_2$",ofst=[0,0]).linestyle("--")
    I1 = flow.Start(w=2,h=0.8).label('Initiating\nAgent 1')
    flow.Arrow(arrowwidth=0.01).right(d.unit).at(I1.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    CS2 = flow.Start(w=2.3,h=0.8).anchor('S').label('Calcium\nSulphate 2')
    flow.Wire('|-', arrow='->').at(CS2.N).to(I2.E).label(r"$1-x_2$",ofst=[1.1,-0.6]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(UPR2.S).reverse().label(r"$x_1$",ofst=[0,0]).linestyle("--")
    UPR1 = flow.Start(w=3,h=0.8).label('Unsaturated\nPolyester Resin 1')
    flow.Arrow(arrowwidth=0.01).right(d.unit/2).at(UPR1.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    DMI2 = flow.Start(w=2.3,h=0.8).anchor('S').label('Dimethyl\nItaconate 2')
    flow.Wire('|-', arrow='->').at(DMI2.N).to(UPR2.E).label(r"$1-x_1$",ofst=[0.8,-0.6]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(I1.S).reverse().label(r"$1-c_2$",ofst=[0,0])
    DBP = flow.Start(w=2.3,h=0.8).label('Dibenzoyl\nPeroxide')
    flow.Arrow(arrowwidth=0.01).right(d.unit*0.85).at(DBP.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    CS2 = flow.Start(w=2.3,h=0.8).anchor('S').label('Calcium\nSulphate 1')
    flow.Wire('|-', arrow='->').at(CS2.N).to(I1.E).label(r"$c_2$",ofst=[0.8,-0.6])

    flow.Arrow().down(d.unit*2.5).at(UPR1.S).reverse().label(r"$c_1$",ofst=[0,0])
    UP = flow.Start(w=2.3,h=0.8).label('Unsaturated\nPolyester')
    flow.Arrow(arrowwidth=0.01).right(d.unit*0.85).at(UP.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    DMI1 = flow.Start(w=2.3,h=0.8).anchor('S').label('Dimethyl\nItaconate 1')
    flow.Wire('|-', arrow='->').at(DMI1.N).to(UPR1.E).label(r"$1-c_1$",ofst=[0.8,-0.6])

    # Legend Item 1 (variable elements)
    flow.Arrow(arrowwidth=0.01).at(DBP.W).down(d.unit*1.2).linewidth(0.01).color('white') # hacky gap
    VarComp = flow.Start(w=5.3,h=0.5).anchor("W").label('Variable Composition Mixture').linestyle("--")
    flow.Arrow().at(VarComp.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*3.5).label("Variable Mass Ratio",ofst=[0,-0.1]).linestyle("--")

    # Legend Item 2 (invariable elements)
    flow.Arrow(arrowwidth=0.01).at(VarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    InVarComp = flow.Start(w=5.3,h=0.5).anchor("W").label('Invariable Composition Mixture').linestyle("-")
    flow.Arrow(arrowwidth=0.01).at(InVarComp.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*3.5).label("Invariable Mass Ratio",ofst=[0,-0.1])

    # Legend Item 2 (invariable elements)
    flow.Arrow(arrowwidth=0.01).at(InVarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    InVarChem = flow.Box(w=5.3,h=0.5).anchor("W").label('Invariable Composition Chemical').linestyle("-")

    # # Legend Item 3 (Manufacturing Notes)
    # flow.Arrow(arrowwidth=0.01).at(InVarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    # SubProcess = flow.Box(w=9.2,h=0.5).anchor("W").label('Sub-Process').linestyle(":")

    # Manufacturer Box
    flow.Arrow(arrowwidth=0.01).at(I1.W).down(d.unit*1.65).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.3).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.55,h=4.6).anchor("W").color("#43aa8b").linestyle(":").label("E",ofst=[2,2])

    # UPR Synthesis Box
    flow.Arrow(arrowwidth=0.01).at(UPR1.W).down(d.unit*1.65).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.1).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.85,h=4.6).anchor("W").color("#90be6d").linestyle(":").label("F",ofst=[2.15,2])

    # I2 Mixing Box
    flow.Arrow(arrowwidth=0.01).at(I2.W).down(d.unit*1.8).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.15).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.55,h=4.8).anchor("W").color("#f3722c").linestyle(":").label("C",ofst=[2,2.1])

    # UPR2 Mixing Box
    flow.Arrow(arrowwidth=0.01).at(UPR2.W).down(d.unit*1.8).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.25).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=5.2,h=4.8).anchor("W").color("#f9c74f").linestyle(":").label("D",ofst=[2.32,2.1])

    # IUPR Mixing Box
    flow.Arrow(arrowwidth=0.01).at(IUPR.W).down(d.unit*1.1).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*2).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=10.4,h=3.3).anchor("W").color("#577590").linestyle(":").label("B",ofst=[4.9,1.3])

    # IUPR Curing
    flow.Arrow(arrowwidth=0.01).at(CUPR.W).down(d.unit*1).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.4).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.9,h=3.2).anchor("W").color("#f94144").linestyle(":").label("A",ofst=[2.2,1.3])

    d.save('CompositePreparation.png',transparent=False,dpi=1000)

# %% [markdown]
# # Attempt 4

# %%
with schemdraw.Drawing() as d:
    d.config(fontsize=11,unit=1)
    CUPR = flow.Start(w=4,h=0.8).label('Cured Unsaturated\nPolyester Resin').linestyle("--")

    flow.Arrow(arrowwidth=0.01).right(d.unit*3).at(CUPR.W).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*2).linewidth(0.01).color('white') # hacky gap
    IUPR = flow.Start(w=4,h=0.8).label('Initiated Unsaturated\nPolyester Resin').linestyle("--").label("1) "+r"3 hr @ 80$^{\circ}$C",ofst=[1.25,1.2])
    a = flow.Line().at(IUPR.N).up(d.unit*0.9).label("2) "+r"1 hr @ 120$^{\circ}$C",ofst=[0,-2.6]).linestyle("-.")
    flow.Wire('-|', arrow='->').at(a.end).to(CUPR.S).label("Heating",ofst=[0.8,-0.7]).linestyle("-.")

    flow.Arrow(arrowwidth=0.01).right(d.unit*2).at(CUPR.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*0.0001).linewidth(0.01).color('white') # hacky gap
    MUPR = flow.Start(w=3,h=1.1).anchor("W").label('Machined\nUnsaturated\nPolyester Resin').linestyle("--")
    b = flow.Arrow().at(CUPR.E).to(MUPR.W).label("Grinding",ofst=[-0.2,-0.1]).linestyle("-.")

    

# 
# "\n"
# ,loc="bottom").label("Heating",loc="top")

    flow.Arrow(arrowwidth=0.01).left(d.unit/1.5).at(IUPR.W).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*1.1).linewidth(0.01).color('white') # hacky gap
    I2 = flow.Start(w=2,h=0.8).label('Initiating\nAgent 2').linestyle("--")
    flow.Wire('|-', arrow='->').at(I2.N).to(IUPR.W).label(r"$1-x_3$",ofst=[-0.9,-0.5]).linestyle("--")

    flow.Arrow(arrowwidth=0.01).right(d.unit/1.2).at(IUPR.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*1.1).linewidth(0.01).color('white') # hacky gap
    UPR2 = flow.Start(w=3,h=0.8).label('Unsaturated\nPolyester Resin 2').linestyle("--")
    flow.Wire('|-', arrow='->').at(UPR2.N).to(IUPR.E).label(r"$x_3$",ofst=[0.7,-0.5]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(I2.S).reverse().label(r"$x_2$",ofst=[0,0]).linestyle("--")
    I1 = flow.Start(w=2,h=0.8).label('Initiating\nAgent 1')
    flow.Arrow(arrowwidth=0.01).right(d.unit).at(I1.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    CS2 = flow.Process(w=2,h=0.8).anchor('S').label('Calcium\nSulphate 2')
    flow.Wire('|-', arrow='->').at(CS2.N).to(I2.E).label(r"$1-x_2$",ofst=[1.1,-0.6]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(UPR2.S).reverse().label(r"$x_1$",ofst=[0,0]).linestyle("--")
    UPR1 = flow.Start(w=3,h=0.8).label('Unsaturated\nPolyester Resin 1')
    flow.Arrow(arrowwidth=0.01).right(d.unit/2).at(UPR1.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    DMI2 = flow.Process(w=2,h=0.8).anchor('S').label('Dimethyl\nItaconate 2')
    flow.Wire('|-', arrow='->').at(DMI2.N).to(UPR2.E).label(r"$1-x_1$",ofst=[0.8,-0.6]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(I1.S).reverse().label(r"$1-c_2$",ofst=[0,0])
    DBP = flow.Process(w=2,h=0.8).label('Dibenzoyl\nPeroxide')
    flow.Arrow(arrowwidth=0.01).right(d.unit*0.85).at(DBP.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    CS2 = flow.Process(w=2,h=0.8).anchor('S').label('Calcium\nSulphate 1')
    flow.Wire('|-', arrow='->').at(CS2.N).to(I1.E).label(r"$c_2$",ofst=[0.8,-0.6])

    flow.Arrow().down(d.unit*2.5).at(UPR1.S).reverse().label(r"$c_1$",ofst=[0,0])
    UP = flow.Process(w=2.2,h=0.8).label('Unsaturated\nPolyester')
    flow.Arrow(arrowwidth=0.01).right(d.unit*0.85).at(UP.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    DMI1 = flow.Process(w=2,h=0.8).anchor('S').label('Dimethyl\nItaconate 1')
    flow.Wire('|-', arrow='->').at(DMI1.N).to(UPR1.E).label(r"$1-c_1$",ofst=[0.8,-0.6])

    # Legend Item 1 (variable elements)
    flow.Arrow(arrowwidth=0.01).at(DBP.W).down(d.unit*1.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.3).linewidth(0.01).color('white') # hacky gap
    VarComp = flow.Start(w=5.4,h=0.5).anchor("W").label('Variable Composition Mixture').linestyle("--")
    flow.Arrow().at(VarComp.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*0.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*4.3).label("Mixing (Variable Ratio)",ofst=[0,-0.05]).linestyle("--")

    # Legend Item 2 (invariable elements)
    flow.Arrow(arrowwidth=0.01).at(VarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    InVarComp = flow.Start(w=5.4,h=0.5).anchor("W").label('Invariable Composition Mixture').linestyle("-")
    flow.Arrow(arrowwidth=0.01).at(InVarComp.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*0.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*4.3).label("Mixing (Invariable Ratio)",ofst=[0,-0.05])

    # Legend Item 3 (invariable elements)
    flow.Arrow(arrowwidth=0.01).at(InVarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    InVarChem = flow.Box(w=5.4,h=0.5).anchor("W").label('Invariable Composition Substance').linestyle("-")
    flow.Arrow(arrowwidth=0.01).at(InVarChem.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*0.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*4.3).label("Other Form of Processing",ofst=[0,-0.05]).linestyle("-.")

    # # Legend Item 4 (Sub-processes)
    flow.Arrow(arrowwidth=0.01).at(InVarChem.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    SubProcess = flow.Box(w=10.3,h=0.5).anchor("W").label('Sub-Process').linestyle(":")

    # Manufacturer Box
    flow.Arrow(arrowwidth=0.01).at(I1.W).down(d.unit*1.65).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.3).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.55,h=4.6).anchor("W").color("#43aa8b").linestyle(":").label("F",ofst=[2,2])

    # UPR Synthesis Box
    flow.Arrow(arrowwidth=0.01).at(UPR1.W).down(d.unit*1.65).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.1).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.85,h=4.6).anchor("W").color("#90be6d").linestyle(":").label("G",ofst=[2.15,2])

    # I2 Mixing Box
    flow.Arrow(arrowwidth=0.01).at(I2.W).down(d.unit*1.8).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.15).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.55,h=4.8).anchor("W").color("#f3722c").linestyle(":").label("D",ofst=[2,2.1])

    # UPR2 Mixing Box
    flow.Arrow(arrowwidth=0.01).at(UPR2.W).down(d.unit*1.8).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.25).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=5.2,h=4.8).anchor("W").color("#f9c74f").linestyle(":").label("E",ofst=[2.32,2.1])

    # IUPR Mixing Box
    flow.Arrow(arrowwidth=0.01).at(IUPR.W).down(d.unit*1.1).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*2).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=10.4,h=3.3).anchor("W").color("#577590").linestyle(":").label("C",ofst=[4.9,1.3])

    # IUPR Curing
    flow.Arrow(arrowwidth=0.01).at(CUPR.W).down(d.unit*1.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.8).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=6.4,h=3.6).anchor("W").color("#f94144").linestyle(":").label("B",ofst=[-2.9,1.5])

    # CUPR Machining
    flow.Arrow(arrowwidth=0.01).at(CUPR.W).down(d.unit*0.01).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.2).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=9.6,h=1.6).anchor("W").color("#be0aff").linestyle(":").label("A",ofst=[4.55,0.5])

    d.save('CompositePreparation.png',transparent=False,dpi=1000)

# %% [markdown]
# # Attempt 5

# %%
with schemdraw.Drawing() as d:
    d.config(fontsize=11,unit=1)
    CUPR = flow.Start(w=4,h=0.8).label('Cured Unsaturated\nPolyester Resin').linestyle("--")

    flow.Arrow(arrowwidth=0.01).right(d.unit*3).at(CUPR.W).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*2).linewidth(0.01).color('white') # hacky gap
    IUPR = flow.Start(w=4,h=0.8).label('Initiated Unsaturated\nPolyester Resin').linestyle("--").label("1) "+r"3 hr @ 80$^{\circ}$C",ofst=[1.25,1.2])
    a = flow.Line().at(IUPR.N).up(d.unit*0.9).label("2) "+r"1 hr @ 120$^{\circ}$C",ofst=[0,-2.6]).linestyle("-.")
    flow.Wire('-|', arrow='->').at(a.end).to(CUPR.S).label("Heating",ofst=[0.8,-0.7]).linestyle("-.")

    flow.Arrow(arrowwidth=0.01).right(d.unit*2).at(CUPR.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*0.0001).linewidth(0.01).color('white') # hacky gap
    MUPR = flow.Start(w=3,h=1.1).anchor("W").label('Machined\nUnsaturated\nPolyester Resin').linestyle("--")
    b = flow.Arrow().at(CUPR.E).to(MUPR.W).label("Grinding",ofst=[-0.2,-0.1]).linestyle("-.")

    flow.Arrow(arrowwidth=0.01).left(d.unit/1.5).at(IUPR.W).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*1.1).linewidth(0.01).color('white') # hacky gap
    I2 = flow.Start(w=2,h=1.1).label('Modified\nInitiating\nAgent').linestyle("--")
    flow.Wire('|-', arrow='->').at(I2.N).to(IUPR.W).label(r"$1-x_3$",ofst=[-0.9,-0.5]).linestyle("--")

    flow.Arrow(arrowwidth=0.01).right(d.unit/1.2).at(IUPR.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*1.1).linewidth(0.01).color('white') # hacky gap
    UPR2 = flow.Start(w=3,h=1.1).label('Modified\nUnsaturated\nPolyester Resin').linestyle("--")
    flow.Wire('|-', arrow='->').at(UPR2.N).to(IUPR.E).label(r"$x_3$",ofst=[0.7,-0.5]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(I2.S).reverse().label(r"$x_2$",ofst=[0,0]).linestyle("--")
    I1 = flow.Start(w=2,h=1.1).label('Base\nInitiating\nAgent')
    flow.Arrow(arrowwidth=0.01).right(d.unit).at(I1.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    CS2 = flow.Process(w=2,h=0.8).anchor('S').label('Calcium\nSulphate 2')
    flow.Wire('|-', arrow='->').at(CS2.N).to(I2.E).label(r"$1-x_2$",ofst=[1.1,-0.6]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(UPR2.S).reverse().label(r"$x_1$",ofst=[0,0]).linestyle("--")
    UPR1 = flow.Start(w=3,h=1.1).label('Base\nUnsaturated\nPolyester Resin')
    flow.Arrow(arrowwidth=0.01).right(d.unit/2).at(UPR1.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    DMI2 = flow.Process(w=2,h=0.8).anchor('S').label('Dimethyl\nItaconate 2')
    flow.Wire('|-', arrow='->').at(DMI2.N).to(UPR2.E).label(r"$1-x_1$",ofst=[0.8,-0.6]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(I1.S).reverse().label(r"$1-c_2$",ofst=[0,0])
    DBP = flow.Process(w=2,h=0.8).label('Dibenzoyl\nPeroxide')
    flow.Arrow(arrowwidth=0.01).right(d.unit*0.85).at(DBP.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    CS2 = flow.Process(w=2,h=0.8).anchor('S').label('Calcium\nSulphate 1')
    flow.Wire('|-', arrow='->').at(CS2.N).to(I1.E).label(r"$c_2$",ofst=[0.8,-0.6])

    flow.Arrow().down(d.unit*2.5).at(UPR1.S).reverse().label(r"$c_1$",ofst=[0,0])
    UP = flow.Process(w=2.2,h=0.8).label('Unsaturated\nPolyester')
    flow.Arrow(arrowwidth=0.01).right(d.unit*0.85).at(UP.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    DMI1 = flow.Process(w=2,h=0.8).anchor('S').label('Dimethyl\nItaconate 1')
    flow.Wire('|-', arrow='->').at(DMI1.N).to(UPR1.E).label(r"$1-c_1$",ofst=[0.8,-0.6])

    # Legend Item 1 (variable elements)
    flow.Arrow(arrowwidth=0.01).at(DBP.W).down(d.unit*1.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.3).linewidth(0.01).color('white') # hacky gap
    VarComp = flow.Start(w=5.4,h=0.5).anchor("W").label('Variable Composition Mixture').linestyle("--")
    flow.Arrow().at(VarComp.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*0.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*4.3).label("Mixing (Variable Ratio)",ofst=[0,-0.05]).linestyle("--")

    # Legend Item 2 (invariable elements)
    flow.Arrow(arrowwidth=0.01).at(VarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    InVarComp = flow.Start(w=5.4,h=0.5).anchor("W").label('Invariable Composition Mixture').linestyle("-")
    flow.Arrow(arrowwidth=0.01).at(InVarComp.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*0.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*4.3).label("Mixing (Invariable Ratio)",ofst=[0,-0.05])

    # Legend Item 3 (invariable elements)
    flow.Arrow(arrowwidth=0.01).at(InVarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    InVarChem = flow.Box(w=5.4,h=0.5).anchor("W").label('Invariable Composition Substance').linestyle("-")
    flow.Arrow(arrowwidth=0.01).at(InVarChem.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*0.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*4.3).label("Other Form of Processing",ofst=[0,-0.05]).linestyle("-.")

    # # Legend Item 4 (Sub-processes)
    flow.Arrow(arrowwidth=0.01).at(InVarChem.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    SubProcess = flow.Box(w=10.3,h=0.5).anchor("W").label('Sub-Process').linestyle(":")

    # Manufacturer Box
    flow.Arrow(arrowwidth=0.01).at(I1.W).down(d.unit*1.65).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.3).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.55,h=4.8).anchor("W").color("#43aa8b").linestyle(":").label("F",ofst=[2,2])

    # UPR Synthesis Box
    flow.Arrow(arrowwidth=0.01).at(UPR1.W).down(d.unit*1.65).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.1).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.85,h=4.8).anchor("W").color("#90be6d").linestyle(":").label("G",ofst=[2.15,2])

    # I2 Mixing Box
    flow.Arrow(arrowwidth=0.01).at(I2.W).down(d.unit*2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.15).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.55,h=5.4).anchor("W").color("#f3722c").linestyle(":").label("D",ofst=[2,2.4])

    # UPR2 Mixing Box
    flow.Arrow(arrowwidth=0.01).at(UPR2.W).down(d.unit*2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.25).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=5.2,h=5.4).anchor("W").color("#f9c74f").linestyle(":").label("E",ofst=[2.32,2.4])

    # IUPR Mixing Box
    flow.Arrow(arrowwidth=0.01).at(IUPR.W).down(d.unit*1.1).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*2).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=10.4,h=3.3).anchor("W").color("#577590").linestyle(":").label("C",ofst=[4.9,1.3])

    # IUPR Curing
    flow.Arrow(arrowwidth=0.01).at(CUPR.W).down(d.unit*1.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.8).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=6.4,h=3.6).anchor("W").color("#f94144").linestyle(":").label("B",ofst=[-2.9,1.5])

    # CUPR Machining
    flow.Arrow(arrowwidth=0.01).at(CUPR.W).down(d.unit*0.01).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.2).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=9.6,h=1.6).anchor("W").color("#be0aff").linestyle(":").label("A",ofst=[4.55,0.5])

    d.save('CompositePreparation.png',transparent=False,dpi=1000)

# %% [markdown]
# # Attempt 6

# %%
with schemdraw.Drawing() as d:
    d.config(fontsize=11,unit=1)
    CUPR = flow.Start(w=4,h=0.8).label('Cured Unsaturated\nPolyester Resin').linestyle("--")

    flow.Arrow(arrowwidth=0.01).right(d.unit*3).at(CUPR.W).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*2).linewidth(0.01).color('white') # hacky gap
    IUPR = flow.Start(w=4,h=0.8).label('Initiated Unsaturated\nPolyester Resin').linestyle("--").label("1) "+r"3 hr @ 80$^{\circ}$C",ofst=[1.25,1.2])
    a = flow.Line().at(IUPR.N).up(d.unit*0.9).label("2) "+r"1 hr @ 120$^{\circ}$C",ofst=[0,-2.6]).linestyle("-.")
    flow.Wire('-|', arrow='->').at(a.end).to(CUPR.S).label("Heating",ofst=[0.8,-0.7]).linestyle("-.")

    flow.Arrow(arrowwidth=0.01).right(d.unit*2).at(CUPR.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*0.0001).linewidth(0.01).color('white') # hacky gap
    MUPR = flow.Start(w=3,h=1.1).anchor("W").label('Machined\nUnsaturated\nPolyester Resin').linestyle("--")
    b = flow.Arrow().at(CUPR.E).to(MUPR.W).label("Grinding",ofst=[-0.2,-0.1]).linestyle("-.")

    flow.Arrow(arrowwidth=0.01).left(d.unit/1.5).at(IUPR.W).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*1.1).linewidth(0.01).color('white') # hacky gap
    I2 = flow.Start(w=2,h=1.1).label('Modified\nInitiating\nAgent').linestyle("--")
    flow.Wire('|-', arrow='->').at(I2.N).to(IUPR.W).label(r"$1-x_3$",ofst=[-0.9,-0.5]).linestyle("--")

    flow.Arrow(arrowwidth=0.01).right(d.unit/1.2).at(IUPR.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*1.1).linewidth(0.01).color('white') # hacky gap
    UPR2 = flow.Start(w=3,h=1.1).label('Modified\nUnsaturated\nPolyester Resin').linestyle("--")
    flow.Wire('|-', arrow='->').at(UPR2.N).to(IUPR.E).label(r"$x_3$",ofst=[0.7,-0.5]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(I2.S).reverse().label(r"$x_2$",ofst=[0,0]).linestyle("--")
    I1 = flow.Start(w=2,h=1.1).label('Base\nInitiating\nAgent')
    flow.Arrow(arrowwidth=0.01).right(d.unit).at(I1.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    CS2 = flow.Process(w=2,h=0.8).anchor('S').label('Calcium\nSulphate 2')
    flow.Wire('|-', arrow='->').at(CS2.N).to(I2.E).label(r"$1-x_2$",ofst=[1.1,-0.6]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(UPR2.S).reverse().label(r"$x_1$",ofst=[0,0]).linestyle("--")
    UPR1 = flow.Start(w=3,h=1.1).label('Base\nUnsaturated\nPolyester Resin')
    flow.Arrow(arrowwidth=0.01).right(d.unit/2).at(UPR1.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    DMI2 = flow.Process(w=2,h=0.8).anchor('S').label('Dimethyl\nItaconate 2')
    flow.Wire('|-', arrow='->').at(DMI2.N).to(UPR2.E).label(r"$1-x_1$",ofst=[0.8,-0.6]).linestyle("--")

    flow.Arrow().down(d.unit*2.5).at(I1.S).reverse().label(r"$1-c_2$",ofst=[0,0])
    DBP = flow.Process(w=2,h=0.8).label('Dibenzoyl\nPeroxide')
    flow.Arrow(arrowwidth=0.01).right(d.unit*0.85).at(DBP.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    CS2 = flow.Process(w=2,h=0.8).anchor('S').label('Calcium\nSulphate 1')
    flow.Wire('|-', arrow='->').at(CS2.N).to(I1.E).label(r"$c_2$",ofst=[0.8,-0.6])

    flow.Arrow().down(d.unit*2.5).at(UPR1.S).reverse().label(r"$c_1$",ofst=[0,0])
    UP = flow.Process(w=2.2,h=0.8).label('Unsaturated\nPolyester')
    flow.Arrow(arrowwidth=0.01).right(d.unit*0.85).at(UP.E).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).up(d.unit).linewidth(0.01).color('white') # hacky gap
    DMI1 = flow.Process(w=2,h=0.8).anchor('S').label('Dimethyl\nItaconate 1')
    flow.Wire('|-', arrow='->').at(DMI1.N).to(UPR1.E).label(r"$1-c_1$",ofst=[0.8,-0.6])

    # Legend Item 1 (variable elements)
    flow.Arrow(arrowwidth=0.01).at(DBP.W).down(d.unit*1.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.3).linewidth(0.01).color('white') # hacky gap
    VarComp = flow.Start(w=5.4,h=0.5).anchor("W").label('Variable Composition Mixture').linestyle("--")
    flow.Arrow().at(VarComp.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*0.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*4.3).label("Mixing (Variable Ratio)",ofst=[0,-0.05]).linestyle("--")

    # Legend Item 2 (invariable elements)
    flow.Arrow(arrowwidth=0.01).at(VarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    InVarComp = flow.Start(w=5.4,h=0.5).anchor("W").label('Invariable Composition Mixture').linestyle("-")
    flow.Arrow(arrowwidth=0.01).at(InVarComp.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*0.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*4.3).label("Mixing (Invariable Ratio)",ofst=[0,-0.05])

    # Legend Item 3 (invariable elements)
    flow.Arrow(arrowwidth=0.01).at(InVarComp.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    InVarChem = flow.Box(w=5.4,h=0.5).anchor("W").label('Invariable Composition Substance').linestyle("-")
    flow.Arrow(arrowwidth=0.01).at(InVarChem.E).right(d.unit*0.5).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).down(d.unit*0.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow().right(d.unit*4.3).label("Other Form of Processing",ofst=[0,-0.05]).linestyle("-.")

    # # Legend Item 4 (Sub-processes)
    flow.Arrow(arrowwidth=0.01).at(InVarChem.W).down(d.unit*0.75).linewidth(0.01).color('white') # hacky gap
    SubProcess = flow.Box(w=10.3,h=0.5).anchor("W").label('Sub-Process').linestyle(":")

    # Manufacturer Box
    flow.Arrow(arrowwidth=0.01).at(I1.W).down(d.unit*1.65).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.3).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.55,h=4.8).anchor("W").color("#43aa8b").linestyle(":").label("F",ofst=[2,2])

    # UPR Synthesis Box
    flow.Arrow(arrowwidth=0.01).at(UPR1.W).down(d.unit*1.65).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.1).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.85,h=4.8).anchor("W").color("#90be6d").linestyle(":").label("G",ofst=[2.15,2])

    # I2 Mixing Box
    flow.Arrow(arrowwidth=0.01).at(I2.W).down(d.unit*2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.15).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=4.55,h=5.4).anchor("W").color("#f3722c").linestyle(":").label("D",ofst=[2,2.4])

    # UPR2 Mixing Box
    flow.Arrow(arrowwidth=0.01).at(UPR2.W).down(d.unit*2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.25).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=5.2,h=5.4).anchor("W").color("#f9c74f").linestyle(":").label("E",ofst=[2.32,2.4])

    # IUPR Mixing Box
    flow.Arrow(arrowwidth=0.01).at(IUPR.W).down(d.unit*1.1).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*2).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=10.4,h=3.3).anchor("W").color("#577590").linestyle(":").label("C",ofst=[4.9,1.3])

    # IUPR Curing
    flow.Arrow(arrowwidth=0.01).at(CUPR.W).down(d.unit*1.2).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.8).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=6.4,h=3.6).anchor("W").color("#f94144").linestyle(":").label("B",ofst=[-2.9,1.5])

    # CUPR Machining
    flow.Arrow(arrowwidth=0.01).at(CUPR.W).down(d.unit*0.01).linewidth(0.01).color('white') # hacky gap
    flow.Arrow(arrowwidth=0.01).left(d.unit*0.2).linewidth(0.01).color('white') # hacky gap
    flow.Box(w=9.6,h=1.6).anchor("W").color("#be0aff").linestyle(":").label("A",ofst=[4.55,0.5])

    # d.save('CompositePreparation.png',transparent=False,dpi=1000)

    d.save('CompositePreparation.pdf',transparent=False,dpi=1000)
